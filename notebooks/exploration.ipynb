# %% [markdown]
# # 宏觀 Regime 探索筆記
#
# 使用 `main.py` 產出 `output/artifacts/macro_panel.csv` 後，可在此載入 pandas 做額外分析。

# %%
import pandas as pd
from pathlib import Path
ROOT = Path('..').resolve()
df = pd.read_csv(ROOT / 'output' / 'artifacts' / 'macro_panel.csv', index_col=0, parse_dates=True)
df.tail()
